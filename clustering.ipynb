# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
print("Sucessfully loaded libraries!")
# Out:
# Sucessfully loaded libraries!

# %%
df = pd.read_excel('merged-data-COMBINED.xlsx')
df.shape
# Out:
# (142305, 18)

# %%
df.head()
# Out:
#     Basket_ID       Date       Barcode  Sum_Units  Sum_Value  CategoryA  \
# 0  1103084867 2013-04-15  800220505783          2   1.960000         10
# 1  1098000980 2013-03-30  800220505783          2   1.960000         10
# 2  1102258535 2013-04-12  800220505783          3   2.940015         10
# 3  1103084867 2013-04-15  520423907421          2   0.580015         10
# 4  1097579428 2013-03-29  520423907421          2   0.580015         10
#
#    CategoryB  CategoryC  CategoryD CategoryBDescription CategoryCDescription  \
# 0         14        239          2         Grocery Food                 pet
# 1         14        239          2         Grocery Food                 pet
# 2         14        239          2         Grocery Food                 pet
# 3         14        239          2         Grocery Food                 pet
# 4         14        239          2         Grocery Food                 pet
#
#   CategoryDDescription        Card_ID   Age   Gender MaritalStatus  \
# ...

# %%
print("Number of categories in B are: " + str(df['CategoryBDescription'].nunique()))
# Out:
# Number of categories in B are: 33

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = df.select_dtypes(include=numerics)

# %%
newdf_nonull = newdf.dropna()

# %%
pd.plotting.scatter_matrix(newdf_nonull, figsize = (16, 12), hist_kwds=dict(bins=50), cmap="Set1")
plt.show()

# %%
#scaler = preprocessing.StandardScaler().fit(newdf)
#X_scaled = scaler.transform(newdf)
#X_scaled.std(axis=0)

#standard_all = pd.DataFrame(X_scaled)

# %%
#distortions_joined_st = []
#K = range(1, 10)
#for k in K:
#    kmeanModel = KMeans(n_clusters=k)
#    kmeanModel.fit(standard_all)
#    distortions_joined_st.append(kmeanModel.inertia_)

# %%
#plt.figure(figsize=(16,8))
#plt.plot(K, distortions_joined_st, 'bx-')
#plt.xlabel('k')
#plt.ylabel('Distortion')
#plt.title('The Elbow Method showing the optimal k for standardized Dataset')
#plt.show()

# %%
#newdf.columns

# %%
#standard_all.columns = newdf.columns

# %%
plt.figure(figsize=(16,8))
plt.scatter(newdf['Sum_Units'], newdf['Sum_Value'], c = newdf['CategoryB'])
plt.title("Cluster Category B - Sum Units VS Sum Value")
plt.xlabel('Units')
plt.ylabel('Value')
plt.colorbar()
