# %%
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx
import numpy as np

# %%
data = pd.read_csv('merged-data-COMBINED-WOL.csv')

grouped_data_b = data.groupby('Basket_ID')['CategoryBDescription'].apply(lambda x: ', '.join(x)).reset_index()
grouped_data_b = grouped_data_b.rename(columns={'CategoryBDescription': 'items bought'})

item_pairs = {}


for index, row in grouped_data_b.iterrows():
    
    
    items_list = row['items bought'].split(', ')
    
    
    for i in range(len(items_list)-1):
        item_pair = tuple(sorted([items_list[i], items_list[i+1]]))
        if item_pair in item_pairs:
            item_pairs[item_pair] += 1
        else:
            item_pairs[item_pair] = 1


for item_pair, weight in item_pairs.items():
    print(f"{item_pair}: {weight}")
# Out:
# ('Detergents', 'products thatn expire soon'): 1965
# ('Detergents', 'Grocery Food'): 7848
# ('Grocery Food', 'Grocery Food'): 18149
# ('DAIRY PRODUCTS', 'Deli and canned food'): 677
# ('Deli and canned food', 'Grocery Food'): 1536
# ('Grocery Food', 'products thatn expire soon'): 6132
# ('products thatn expire soon', 'products thatn expire soon'): 2587
# ('DAIRY PRODUCTS', 'products thatn expire soon'): 2196
# ('DAIRY PRODUCTS', 'Grocery Food'): 5631
# ('Grocery Food', 'household'): 1451
# ('DAIRY PRODUCTS', 'household'): 304
# ('DAIRY PRODUCTS', 'DAIRY PRODUCTS'): 1118
# ('DAIRY PRODUCTS', 'Detergents'): 1660
# ('Grocery Food', 'traditional butchery'): 1308
# ('traditional butchery', 'traditional butchery'): 491
# ('Grocery Food', 'frozen'): 1901
# ('Detergents', 'Detergents'): 4499
# ('Grocery Food', 'fruits and vegetables'): 6405
# ('Deli and canned food', 'fruits and vegetables'): 439
# ('DRINKS', 'Grocery Food'): 5837
# ('Detergents', 'fruits and vegetables'): 1746
# ('DAIRY PRODUCTS', 'DRINKS'): 924
# ('COLD CUTS', 'DAIRY PRODUCTS'): 290
# ('COLD CUTS', 'Grocery Food'): 776
# ('DRINKS', 'Detergents'): 1824
# ('fruits and vegetables', 'products thatn expire soon'): 2545
# ('DAIRY PRODUCTS', 'fruits and vegetables'): 2008
# ('Detergents', 'traditional butchery'): 393
# ('DAIRY PRODUCTS', 'hardware'): 18
# ('Detergents', 'hardware'): 100
# ('Detergents', 'household'): 961
# ('books-paper-music-video', 'household'): 38
# ('COLD CUTS', 'DRINKS'): 198
# ('COLD CUTS', 'household'): 37
# ('Deli and canned food', 'Detergents'): 376
# ('Deli and canned food', 'Deli and canned food'): 202
# ('Deli and canned food', 'bakery'): 141
# ('bakery', 'bed and kitchen '): 1
# ('Detergents', 'frozen'): 628
# ('DAIRY PRODUCTS', 'frozen'): 443
# ('bakery', 'products thatn expire soon'): 392
# ('bakery', 'household'): 51
# ('bakery', 'pastry making'): 51
# ('DRINKS', 'products thatn expire soon'): 1386
# ('Deli and canned food', 'household'): 75
# ('DAIRY PRODUCTS', 'traditional butchery'): 345
# ('Detergents', 'bakery'): 347
# ('COLD CUTS', 'Detergents'): 229
# ('frozen', 'salted fish'): 20
# ('salted fish', 'shoes'): 1
# ('fruits and vegetables', 'fruits and vegetables'): 4012
# ('bakery', 'fruits and vegetables'): 499
# ('Grocery Food', 'bakery'): 1279
# ('DRINKS', 'bakery'): 341
# ('DRINKS', 'DRINKS'): 1858
# ('frozen', 'products thatn expire soon'): 388
# ('frozen', 'frozen'): 568
# ('COLD CUTS', 'frozen'): 111
# ('COLD CUTS', 'products thatn expire soon'): 156
# ('fruits and vegetables', 'traditional butchery'): 544
# ('DRINKS', 'fruits and vegetables'): 1317
# ('DAIRY PRODUCTS', 'bakery'): 325
# ('Deli and canned food', 'products thatn expire soon'): 317
# ('DRINKS', 'Deli and canned food'): 264
# ('Grocery Food', 'hardware'): 166
# ('Detergents', 'GARDENING'): 52
# ('DRINKS', 'hardware'): 46
# ('bakery', 'bakery'): 106
# ('frozen', 'fruits and vegetables'): 657
# ('household', 'products thatn expire soon'): 339
# ('DRINKS', 'frozen'): 392
# ('COLD CUTS', 'bakery'): 75
# ('household', 'household'): 367
# ('bakery', 'frozen'): 177
# ('DRINKS', 'household'): 308
# ('DRINKS', 'traditional butchery'): 328
# ('COLD CUTS', 'COLD CUTS'): 86
# ('GARDENING', 'products thatn expire soon'): 24
# ('Detergents', 'books-paper-music-video'): 96
# ('GARDENING', 'household'): 11
# ('GARDENING', 'GARDENING'): 10
# ('GARDENING', 'Grocery Food'): 99
# ('Detergents', 'butchery'): 12
# ('products thatn expire soon', 'traditional butchery'): 259
# ('Grocery Food', 'pastry making'): 283
# ('fruits and vegetables', 'hardware'): 43
# ('Grocery Food', 'shoes'): 81
# ('Detergents', 'pastry making'): 121
# ('COLD CUTS', 'fruits and vegetables'): 214
# ('DAIRY PRODUCTS', 'pastry making'): 64
# ('frozen', 'household'): 115
# ('COLD CUTS', 'salted fish'): 5
# ('COLD CUTS', 'Deli and canned food'): 79
# ('Detergents', 'shoes'): 44
# ('pastry making', 'products thatn expire soon'): 96
# ('DRINKS', 'GARDENING'): 23
# ('Detergents', 'salted fish'): 16
# ('Grocery Food', 'underwear'): 68
# ('underwear', 'underwear'): 29
# ('fruits and vegetables', 'household'): 368
# ('DAIRY PRODUCTS', 'traditional fisherman'): 24
# ('fruits and vegetables', 'traditional fisherman'): 16
# ('Fresh poultry', 'frozen'): 13
# ('Detergents', 'Fresh poultry'): 18
# ('butchery', 'fruits and vegetables'): 19
# ('butchery', 'traditional butchery'): 9
# ('GARDENING', 'fruits and vegetables'): 23
# ('frozen', 'traditional fisherman'): 29
# ('DAIRY PRODUCTS', 'salted fish'): 16
# ('COLD CUTS', 'GARDENING'): 3
# ('Grocery Food', 'gifts'): 19
# ('COLD CUTS', 'pastry making'): 7
# ('books-paper-music-video', 'frozen'): 16
# ('Deli and canned food', 'frozen'): 193
# ('pastry making', 'shoes'): 3
# ('frozen', 'ice creams'): 24
# ('salted fish', 'traditional butchery'): 4
# ('bakery', 'traditional butchery'): 113
# ('frozen', 'traditional butchery'): 120
# ('Deli and canned food', 'traditional butchery'): 126
# ('DRINKS', 'telephone '): 34
# ('fruits and vegetables', 'telephone '): 9
# ('DAIRY PRODUCTS', 'Fresh poultry'): 19
# ('Fresh poultry', 'Grocery Food'): 74
# ('COLD CUTS', 'traditional butchery'): 62
# ('Grocery Food', 'books-paper-music-video'): 210
# ('books-paper-music-video', 'products thatn expire soon'): 35
# ('DAIRY PRODUCTS', 'GARDENING'): 21
# ('hardware', 'household'): 17
# ('frozen', 'hardware'): 11
# ('pastry making', 'pastry making'): 26
# ('GAME - ENTERTAINMENT ', 'Grocery Food'): 75
# ('Detergents', 'underwear'): 68
# ('Grocery Food', 'bed and kitchen '): 4
# ('bed and kitchen ', 'bed and kitchen '): 2
# ('bed and kitchen ', 'shoes'): 2
# ('Grocery Food', 'butchery'): 61
# ('butchery', 'frozen'): 7
# ('Deli and canned food', 'butchery'): 5
# ('Grocery Food', 'telephone '): 90
# ('DRINKS', 'butchery'): 12
# ('household', 'underwear'): 7
# ('bakery', 'butchery'): 9
# ('DAIRY PRODUCTS', 'butchery'): 9
# ('household', 'traditional butchery'): 59
# ('gifts', 'products thatn expire soon'): 6
# ('gifts', 'hardware'): 2
# ('COLD CUTS', 'hardware'): 4
# ('GARDENING', 'traditional butchery'): 7
# ('butchery', 'products thatn expire soon'): 15
# ('GAME - ENTERTAINMENT ', 'household'): 6
# ('products thatn expire soon', 'telephone '): 40
# ('DAIRY PRODUCTS', 'telephone '): 14
# ('DRINKS', 'salted fish'): 12
# ('products thatn expire soon', 'underwear'): 12
# ('Fresh poultry', 'products thatn expire soon'): 23
# ('books-paper-music-video', 'shoes'): 2
# ('hardware', 'products thatn expire soon'): 37
# ('hardware', 'traditional butchery'): 9
# ('Detergents', 'GAME - ENTERTAINMENT '): 39
# ('gifts', 'pastry making'): 2
# ('bakery', 'telephone '): 8
# ('Deli and canned food', 'underwear'): 6
# ('GAME - ENTERTAINMENT ', 'products thatn expire soon'): 15
# ('Detergents', 'babies clothing'): 2
# ('babies clothing', 'babies clothing'): 3
# ('DRINKS', 'pastry making'): 83
# ('fruits and vegetables', 'ice creams'): 15
# ('DAIRY PRODUCTS', 'ice creams'): 14
# ('Grocery Food', 'house organized'): 6
# ('GARDENING', 'bakery'): 8
# ('Detergents', 'car'): 15
# ('DAIRY PRODUCTS', 'car'): 3
# ('household', 'pastry making'): 24
# ('DRINKS', 'Fresh poultry'): 15
# ('Deli and canned food', 'GARDENING'): 6
# ('fruits and vegetables', 'pastry making'): 92
# ('DRINKS', 'traditional fisherman'): 6
# ('products thatn expire soon', 'shoes'): 18
# ('COLD CUTS', 'telephone '): 4
# ('telephone ', 'traditional butchery'): 2
# ('traditional butchery', 'traditional fisherman'): 10
# ('traditional fisherman', 'traditional fisherman'): 81
# ('GAME - ENTERTAINMENT ', 'books-paper-music-video'): 4
# ('fruits and vegetables', 'shoes'): 11
# ('bakery', 'hardware'): 7
# ('Grocery Food', 'man clothing'): 3
# ('Detergents', 'traditional fisherman'): 23
# ('GARDENING', 'electronic devices'): 1
# ('Grocery Food', 'electronic devices'): 20
# ('books-paper-music-video', 'fruits and vegetables'): 46
# ('shoes', 'shoes'): 17
# ('Grocery Food', 'ice creams'): 105
# ('Detergents', 'ice creams'): 34
# ('products thatn expire soon', 'traditional fisherman'): 10
# ('bakery', 'underwear'): 7
# ('DAIRY PRODUCTS', 'shoes'): 9
# ('Detergents', 'bed and kitchen '): 1
# ('Deli and canned food', 'traditional fisherman'): 11
# ('DAIRY PRODUCTS', 'books-paper-music-video'): 53
# ('pastry making', 'telephone '): 1
# ('Grocery Food', 'traditional fisherman'): 46
# ('shoes', 'traditional fisherman'): 3
# ('babies clothing', 'fruits and vegetables'): 1
# ('pastry making', 'traditional butchery'): 18
# ('DRINKS', 'underwear'): 19
# ('fruits and vegetables', 'underwear'): 14
# ('Grocery Food', 'salted fish'): 62
# ('frozen', 'shoes'): 13
# ('Fresh poultry', 'household'): 2
# ('bakery', 'traditional fisherman'): 6
# ('DRINKS', 'books-paper-music-video'): 43
# ('GAME - ENTERTAINMENT ', 'fruits and vegetables'): 22
# ('DRINKS', 'GAME - ENTERTAINMENT '): 16
# ('car', 'traditional butchery'): 1
# ('DAIRY PRODUCTS', 'GAME - ENTERTAINMENT '): 18
# ('Detergents', 'electronic devices'): 12
# ('frozen', 'pastry making'): 31
# ('DRINKS', 'shoes'): 19
# ('ice creams', 'products thatn expire soon'): 17
# ('GAME - ENTERTAINMENT ', 'traditional butchery'): 4
# ('frozen', 'telephone '): 9
# ('Fresh poultry', 'butchery'): 1
# ('GARDENING', 'car'): 2
# ('car', 'products thatn expire soon'): 6
# ('hardware', 'hardware'): 12
# ('gifts', 'household'): 3
# ('Deli and canned food', 'GAME - ENTERTAINMENT '): 5
# ('butchery', 'butchery'): 1
# ('DRINKS', 'ice creams'): 41
# ('Deli and canned food', 'pastry making'): 23
# ('DAIRY PRODUCTS', 'gifts'): 3
# ('COLD CUTS', 'ice creams'): 3
# ('electronic devices', 'hardware'): 1
# ('Deli and canned food', 'hardware'): 8
# ('Fresh poultry', 'fruits and vegetables'): 11
# ('telephone ', 'telephone '): 11
# ('GARDENING', 'frozen'): 8
# ('household', 'shoes'): 21
# ('DRINKS', 'car'): 7
# ('butchery', 'electronic devices'): 1
# ('Deli and canned food', 'man clothing'): 1
# ('pastry making', 'salted fish'): 1
# ('books-paper-music-video', 'books-paper-music-video'): 36
# ('fruits and vegetables', 'salted fish'): 21
# ('GAME - ENTERTAINMENT ', 'frozen'): 2
# ('butchery', 'pastry making'): 1
# ('Deli and canned food', 'salted fish'): 10
# ('Deli and canned food', 'house organized'): 2
# ('Grocery Food', 'car'): 15
# ('pastry making', 'underwear'): 2
# ('Detergents', 'telephone '): 34
# ('Deli and canned food', 'telephone '): 3
# ('GAME - ENTERTAINMENT ', 'GARDENING'): 3
# ('GARDENING', 'telephone '): 1
# ('COLD CUTS', 'GAME - ENTERTAINMENT '): 2
# ('butchery', 'salted fish'): 1
# ('GARDENING', 'butchery'): 1
# ('GARDENING', 'gifts'): 1
# ('Deli and canned food', 'gifts'): 3
# ('frozen', 'underwear'): 5
# ('bakery', 'salted fish'): 5
# ('COLD CUTS', 'traditional fisherman'): 1
# ('hardware', 'underwear'): 3
# ('GAME - ENTERTAINMENT ', 'underwear'): 1
# ('pastry making', 'traditional fisherman'): 2
# ('COLD CUTS', 'Fresh poultry'): 6
# ('GARDENING', 'hardware'): 7
# ('DAIRY PRODUCTS', 'underwear'): 12
# ('books-paper-music-video', 'underwear'): 2
# ('Deli and canned food', 'books-paper-music-video'): 6
# ('bakery', 'ice creams'): 6
# ('ice creams', 'ice creams'): 20
# ('DAIRY PRODUCTS', 'electronic devices'): 1
# ('Grocery Food', 'babies clothing'): 9
# ('Deli and canned food', 'shoes'): 2
# ('man clothing', 'traditional butchery'): 1
# ('books-paper-music-video', 'traditional butchery'): 7
# ('Fresh poultry', 'bakery'): 4
# ('products thatn expire soon', 'salted fish'): 11
# ('books-paper-music-video', 'hardware'): 1
# ('Fresh poultry', 'pastry making'): 5
# ('shoes', 'underwear'): 3
# ('fruits and vegetables', 'gifts'): 2
# ('Deli and canned food', 'ice creams'): 9
# ('electronic devices', 'products thatn expire soon'): 1
# ('household', 'traditional fisherman'): 4
# ('electronic devices', 'electronic devices'): 2
# ('Fresh poultry', 'Fresh poultry'): 6
# ('DAIRY PRODUCTS', 'house organized'): 1
# ('Detergents', 'house organized'): 13
# ('house organized', 'house organized'): 2
# ('house organized', 'products thatn expire soon'): 4
# ('electronic devices', 'underwear'): 2
# ('car', 'frozen'): 1
# ('hardware', 'salted fish'): 1
# ('ice creams', 'traditional butchery'): 3
# ('DRINKS', 'house organized'): 6
# ('Fresh poultry', 'GARDENING'): 1
# ('bakery', 'electronic devices'): 2
# ('electronic devices', 'household'): 2
# ('COLD CUTS', 'electronic devices'): 2
# ('ice creams', 'salted fish'): 1
# ('Detergents', 'gifts'): 3
# ('Deli and canned food', 'electronic devices'): 2
# ('electronic devices', 'traditional butchery'): 1
# ('Fresh poultry', 'underwear'): 2
# ('salted fish', 'salted fish'): 2
# ('household', 'ice creams'): 9
# ('Deli and canned food', 'Fresh poultry'): 5
# ('Fresh poultry', 'salted fish'): 2
# ('electronic devices', 'fruits and vegetables'): 2
# ('hardware', 'house organized'): 1
# ('GAME - ENTERTAINMENT ', 'traditional fisherman'): 1
# ('COLD CUTS', 'underwear'): 1
# ('GAME - ENTERTAINMENT ', 'hardware'): 1
# ('gifts', 'traditional butchery'): 1
# ('hardware', 'pastry making'): 1
# ('house organized', 'shoes'): 1
# ('Fresh poultry', 'traditional butchery'): 4
# ('house organized', 'household'): 6
# ('Detergents', 'man clothing'): 1
# ('bed and kitchen ', 'products thatn expire soon'): 4
# ('DRINKS', 'gifts'): 4
# ('bakery', 'gifts'): 1
# ('babies clothing', 'products thatn expire soon'): 1
# ('traditional butchery', 'underwear'): 2
# ('shoes', 'traditional butchery'): 2
# ('house organized', 'telephone '): 1
# ('COLD CUTS', 'gifts'): 1
# ('bakery', 'shoes'): 4
# ('butchery', 'household'): 3
# ('electronic devices', 'frozen'): 2
# ('fruits and vegetables', 'house organized'): 1
# ('household', 'salted fish'): 1
# ('bed and kitchen ', 'underwear'): 1
# ('Fresh poultry', 'bed and kitchen '): 1
# ('bakery', 'car'): 3
# ('DAIRY PRODUCTS', 'bed and kitchen '): 1
# ('bed and kitchen ', 'household'): 1
# ('ice creams', 'underwear'): 1
# ('DAIRY PRODUCTS', 'babies clothing'): 1
# ('TV - HIFI - sound', 'ice creams'): 1
# ('ice creams', 'pastry making'): 2
# ('shoes', 'telephone '): 1
# ('COLD CUTS', 'shoes'): 1
# ('hardware', 'ice creams'): 1
# ('car', 'hardware'): 1
# ('hardware', 'telephone '): 1
# ('telephone ', 'underwear'): 1
# ('Grocery Food', 'TV - HIFI - sound'): 1
# ('bakery', 'books-paper-music-video'): 11
# ('GAME - ENTERTAINMENT ', 'pastry making'): 1
# ('man clothing', 'telephone '): 1
# ('DRINKS', 'electronic devices'): 1
# ('ice creams', 'telephone '): 1
# ('car', 'pastry making'): 1
# ('GAME - ENTERTAINMENT ', 'electronic devices'): 1
# ('Fresh poultry', 'house organized'): 1
# ('electronic devices', 'shoes'): 1
# ('telephone ', 'traditional fisherman'): 1
# ('COLD CUTS', 'books-paper-music-video'): 2
# ('GARDENING', 'house organized'): 1
# ('household', 'telephone '): 2
# ('GARDENING', 'ice creams'): 1
# ('books-paper-music-video', 'pastry making'): 1
# ('GARDENING', 'babies clothing'): 1
# ('car', 'fruits and vegetables'): 1
# ('GARDENING', 'books-paper-music-video'): 1
# ('COLD CUTS', 'butchery'): 1
# ('GARDENING', 'shoes'): 1
# ('babies clothing', 'books-paper-music-video'): 1
# ('DRINKS', 'bed and kitchen '): 1
# ('DRINKS', 'babies clothing'): 1

# %% [markdown]
# 374 IDENTIFIED

# %%
top_item_pairs = sorted(item_pairs.items(), key=lambda x: x[1], reverse=True)[:100]

G = nx.Graph()

for pair, weight in top_item_pairs:
    G.add_edge(pair[0], pair[1], weight=weight)

pos = nx.spring_layout(G, k=30, iterations=50)

node_degrees = dict(G.degree())
node_colors = np.array([node_degrees[n] for n in G.nodes()])
cmap = plt.cm.get_cmap('coolwarm', max(node_colors)-min(node_colors)+1)

plt.figure(figsize=(20, 10))
nx.draw_networkx_nodes(G, pos, node_color=node_colors, cmap=cmap, node_size=800)
nx.draw_networkx_labels(G, pos, font_size=10, font_family='sans-serif')

widths = [G[u][v]['weight']/300 for u, v in G.edges()]
nx.draw_networkx_edges(G, pos, width=widths, edge_color='gray', alpha=0.5)

sm = plt.cm.ScalarMappable(cmap=cmap)
sm.set_array([])
plt.colorbar(sm)

plt.title('Top Item Pairs for CatB', fontsize=20, fontweight='bold')
plt.axis('off')
plt.show()
# Out:
# C:\Users\Thilo\AppData\Local\Temp\ipykernel_13820\1845436648.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('coolwarm', max(node_colors)-min(node_colors)+1)
# C:\Users\Thilo\AppData\Local\Temp\ipykernel_13820\1845436648.py:23: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm)
